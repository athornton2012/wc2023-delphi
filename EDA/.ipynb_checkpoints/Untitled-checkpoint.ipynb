# %%
import pandas as pd
import numpy as np

# %%
rating16_22 = pd.read_csv('../Datasets/cleaned_data/FIFA16-22_rating_new.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
rating16_22.head()
# Out:
#    short_name           long_name player_positions  overall  age  height_cm  \
# 0    C. Lloyd  Carli Anne Hollins  CM, CAM, LM, ST       91   32        173
# 1  M. Rapinoe  Megan Anna Rapinoe           LM, CM       90   29        170
# 2  A. Wambach        Abby Wambach               ST       90   35        180
# 3    L. Nécib        Louisa Nécib          LM, CAM       90   28        168
# 4   N. Keßler       Nadine Keßler               CM       89   27        169
#
#    weight_kg nationality_name nation_position preferred_foot  skill_moves  \
# 0         64    United States             LCM          Right            3
# 1         60    United States              LM           Left            4
# 2         81    United States              LS          Right            3
# 3         56           France              LM          Right            4
# 4         61          Germany             SUB          Right            4
#
# ...

# %%
len(rating16_22['short_name'].unique())
# Out:
# 735

# %%
unique_rating = rating16_22.drop_duplicates(subset=['short_name'], keep = 'last')

# %%
unique_rating.shape
# Out:
# (735, 46)

# %%
unique_rating['nationality_name'].value_counts()
# Out:
# Mexico           61
# Brazil           57
# Germany          55
# France           53
# Norway           52
# Spain            48
# United States    46
# Sweden           46
# Canada           44
# Australia        43
# England          41
# China PR         41
# Netherlands      40
# New Zealand      38
# Scotland         24
# Belgium          23
# Portugal         23
# Name: nationality_name, dtype: int64
