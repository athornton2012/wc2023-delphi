# %%
import json
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from operator import itemgetter
import numpy as np
from collections import defaultdict

# %%
sns.set()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44164\2631709286.py in <module>
# ----> 1 sns.set('whitegrid')
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in set(*args, **kwargs)
#     134     This function may be removed in the future.
#     135     """
# --> 136     set_theme(*args, **kwargs)
#     137
#     138
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#     121
#     122     """
# --> 123     set_context(context, font_scale)
#     124     set_style(style, rc={"font.family": font})
#     125     set_palette(palette, color_codes=color_codes)
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in set_context(context, font_scale, rc)
#     475
#     476     """
# --> 477     context_object = plotting_context(context, font_scale, rc)
#     478     mpl.rcParams.update(context_object)
#     479
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in plotting_context(context, font_scale, rc)
#     384         contexts = ["paper", "notebook", "talk", "poster"]
#     385         if context not in contexts:
# --> 386             raise ValueError("context must be in %s" % ", ".join(contexts))
#     387
#     388         # Set up dictionary of default parameters
#
# ValueError: context must be in paper, notebook, talk, poster

# %%
competitions = pd.read_json('../Datasets/statsbomb-open-data/data/competitions.json')

# %%
competitions_female = competitions[competitions['competition_gender'] == 'female']

# %%
competitions_female
# Out:
#     competition_id  season_id              country_name  \
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 38              49          3  United States of America
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 38                     NWSL             female              False
# 41        UEFA Women's Euro             female              False
# 42        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# 15                      False   2020/2021  2023-02-25T14:52:09.326729
# 16                      False   2019/2020  2023-02-25T12:45:18.376026
# 17                      False   2018/2019  2022-12-01T11:41:40.025541
# 38                      False        2018  2022-11-22T00:50:34.050564
# 41                       True        2022  2023-02-22T23:06:39.942980
# 42                       True        2019  2023-04-07T09:00:52.515359
#
#              match_updated_360         match_available_360  \
# 15     2021-06-13T16:17:31.694                        None
# 16     2021-06-13T16:17:31.694                        None
# 17     2021-06-13T16:17:31.694                        None
# 38     2021-06-13T16:17:31.694                        None
# 41  2023-04-14T11:34:39.799826  2023-04-14T11:34:39.799826
# 42     2021-06-13T16:17:31.694                        None
#
#                match_available
# 15  2023-02-25T14:52:09.326729
# 16  2023-02-25T12:45:18.376026
# 17  2022-12-01T11:41:40.025541
# 38  2022-11-22T00:50:34.050564
# 41  2023-02-22T23:06:39.942980
# 42  2023-04-07T09:00:52.515359

# %%
Super_2020 = pd.read_json('../Datasets/statsbomb-open-data/data/matches/37/90.json')

# %%
Super_2019 = pd.read_json('../Datasets/statsbomb-open-data/data/matches/37/42.json')

# %%
Super_2018 = pd.read_json('../Datasets/statsbomb-open-data/data/matches/37/4.json')

# %%
NWSL_2018 = pd.read_json('../Datasets/statsbomb-open-data/data/matches/49/3.json')

# %%
Super_2020.shape
# Out:
# (131, 18)

# %%
Super_2019.shape
# Out:
# (87, 18)

# %%
Super_2018.shape
# Out:
# (108, 18)

# %%
NWSL_2018.shape
# Out:
# (36, 18)

# %%
def get_country_count(league):
    country_ct = {}
    match_list = league['match_id']
    missing_match = []

    for match in match_list:
        try:
            with open('../Datasets/statsbomb-open-data/data/lineups/'+str(match)+'.json', encoding='utf-8') as j:
                match_t = json.load(j)
        except FileNotFoundError:
            missing_match.append(match)
            continue

        for i in range(len(match_t[0]['lineup'])):
            country = match_t[0]['lineup'][i]['country']['name']
            if country in country_ct:
                country_ct[country] += 1
            else:
                country_ct[country] = 1

        for i in range(len(match_t[1]['lineup'])):
            country = match_t[1]['lineup'][i]['country']['name']
            if country in country_ct:
                country_ct[country] += 1
            else:
                country_ct[country] = 1    
           
    return country_ct, missing_match

# %%
Super_2020_country, missing = get_country_count(Super_2020)
print(missing)
# Out:
# []

# %%
Super_2019_country, missing = get_country_count(Super_2019)
print(missing)
# Out:
# []

# %%
Super_2018_country, missing = get_country_count(Super_2018)
print(missing)
# Out:
# []

# %%
NWSL_2018_country, missing  = get_country_count(NWSL_2018)
print(missing)
# Out:
# []

# %%
Super_2020_df =pd.DataFrame(list(Super_2020_country.items()), columns=['nationality', 'Super_2020'])

# %%
Super_2019_df =pd.DataFrame(list(Super_2019_country.items()), columns=['nationality', 'Super_2019'])

# %%
Super_2018_df =pd.DataFrame(list(Super_2018_country.items()), columns=['nationality', 'Super_2018'])

# %%
Super_all = pd.merge(Super_2018_df, Super_2019_df, on='nationality', how = 'outer').merge(
    Super_2020_df, on='nationality', how = 'outer')

# %%
Super_all = Super_all.fillna(0)

# %%
Super_all.isna().sum()
# Out:
# nationality    0
# Super_2018     0
# Super_2019     0
# Super_2020     0
# dtype: int64

# %%
Super_all['Super_2018'] = Super_all['Super_2018'].astype('int')
Super_all['Super_2019'] = Super_all['Super_2019'].astype('int')
Super_all['Super_2020'] = Super_all['Super_2020'].astype('int')

# %%
Super_all
# Out:
#                  nationality  Super_2018  Super_2019  Super_2020
# 0                     Sweden          64          62          80
# 1                     Norway          15         103         195
# 2                    Jamaica          61          29          52
# 3                    England        1680        1532        2430
# 4              Korea (South)          25          36          70
# 5                Switzerland          49          37          78
# 6                   Scotland         241         248         292
# 7   United States of America          54          34          76
# 8                    Denmark          21          18          81
# 9                     Canada          16          28          76
# 10                   Belgium          52          30          22
# 11                   Germany          63          85         159
# 12                   Ireland         186         159         196
# 13                     Wales         213         184         253
# 14          Northern Ireland          69          39          78
# 15                   Finland          26          18          52
# 16               New Zealand          37          28          48
# 17               Netherlands         155         146         175
# 18                    France          13          74          95
# 19                   Nigeria          19          15           0
# 20                   Morocco          16          13          19
# 21                   Austria           6          28          28
# 22                   Iceland           5           4           9
# 23                  Portugal           0          16          20
# 24                 Australia           0          19         178
# 25        Dominican Republic           0          12           9
# 26                    Poland           0           7           2
# 27                     Japan           0           0          13
# 28                    Mexico           0           0           9
# 29                     Spain           0           0          19
# 30            Czech Republic           0           0          16
# 31                    Brazil           0           0           9
# 32                    Greece           0           0           3

# %%
Super_all = Super_all[Super_all['nationality'] != 'England']

# %%
Super_all = Super_all.fillna(0)

# %%
fig, ax = plt.subplots(figsize =(20, 25))
country = Super_all.nationality
Super_2018  = Super_all['Super_2018']
Super_2019  = Super_all['Super_2019']
Super_2020  = Super_all['Super_2020']

ind = np.arange(len(country))
width=0.25 

ax = plt.subplot(111)
ax.barh(ind, Super_2018, width, align='center', alpha=0.6, color='palegreen', label='Super_2018') 
ax.barh(ind - width, Super_2019, width, align='center', alpha=0.6, color='limegreen', label='Super_2019') 
ax.barh(ind - width * 2, Super_2020, width, align='center', alpha=0.6, color='darkgreen', label='Super_2020')  

for i, (x, y1, y2, y3) in enumerate(zip(ind, Super_2018, Super_2019, Super_2020)):
    ax.text(y3 + 0.5, i - width * 2, str(y3), ha='left', va='center', color='black')
    ax.text(y2 + 0.5, i - width, str(y2), ha='left', va='center', color='black')
    ax.text(y1 + 0.5, i, str(y1), ha='left', va='center', color='black')

ax.set(yticks=ind - width/2, yticklabels=country, ylim=[- 1, len(country)])
plt.xlabel('Frequency of Appearance')
plt.title('Frequency of International Players Appearance in FA Super League')
plt.legend()
plt.savefig('../imgs/Statsbomb/Super_country_count.pdf',bbox_inches='tight')

# %%
NWSL_2018_country
# Out:
# {'United States of America': 682,
#  'Canada': 65,
#  'South Africa': 12,
#  'England': 19,
#  'Australia': 61,
#  'Iceland': 9,
#  'Scotland': 9,
#  'New Zealand': 26,
#  'Switzerland': 7,
#  'Japan': 17,
#  'Brazil': 42,
#  'Ireland': 11,
#  'Cameroon': 10,
#  'Jamaica': 7,
#  'Nigeria': 7,
#  'Wales': 5,
#  'Norway': 2,
#  'Costa Rica': 4,
#  'Mexico': 6,
#  'Denmark': 6,
#  'Ghana': 3,
#  'Argentina': 5,
#  'Bosnia and Herzegovina': 2}

# %%
NWSL_2018_country.pop('United States of America')
# Out:
# 682

# %%
def plot_count(country_ct, league):
    country_ct_df = pd.Series(country_ct)
    country_ct_df.sort_values(ascending = False, inplace = True)
    fig, ax = plt.subplots(figsize =(14, 8))
    ax.barh(country_ct_df.index, country_ct_df.values, color = 'lightseagreen', height = 0.4)
    ax.invert_yaxis()
    for i in ax.patches:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,
                 str(round((i.get_width()), 2)),
                 fontsize = 10, fontweight ='bold',
                 color ='grey')
    ax.set_title('Frequency of International Players Appearance in '+ league,
                 loc ='left')
    plt.savefig('../imgs/Statsbomb/NWSL_country_count.pdf',bbox_inches='tight')

# %%
plot_count(NWSL_2018_country, 'NWSL_2018')
