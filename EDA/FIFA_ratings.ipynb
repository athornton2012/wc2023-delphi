# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import json
import time
from mlxtend.plotting import category_scatter
from matplotlib import cm

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)

# %%
sns.set()

# %%
rating16_22 = pd.read_csv('../Datasets/cleaned_data/FIFA16-22_rating_new.csv')

# %%
rating16_22.head()
# Out:
#    short_name           long_name player_positions  overall  age  height  \
# 0    C. Lloyd  Carli Anne Hollins  CM, CAM, LM, ST       91   32     173
# 1  M. Rapinoe  Megan Anna Rapinoe           LM, CM       90   29     170
# 2  A. Wambach        Abby Wambach               ST       90   35     180
# 3    L. Nécib        Louisa Nécib          LM, CAM       90   28     168
# 4   N. Keßler       Nadine Keßler               CM       89   27     169
#
#    weight    nationality nation_position preferred_foot  skill_moves  pace  \
# 0      64  United States             LCM          Right            3  75.0
# 1      60  United States              LM           Left            4  74.0
# 2      81  United States              LS          Right            3  72.0
# 3      56         France              LM          Right            4  84.0
# 4      61        Germany             SUB          Right            4  74.0
#
#    shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 0      83.0     83.0       85.0       82.0    84.0                  72
# 1      74.0     90.0       89.0       46.0    68.0                  94
# 2      89.0     65.0       80.0       39.0    82.0                  53
# 3      74.0     87.0       90.0       53.0    69.0                  84
# 4      84.0     85.0       83.0       78.0    74.0                  76
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   83                          71                       88
# 1                   73                          65                       93
# 2                   93                          91                       71
# 3                   76                          58                       91
# 4                   87                          76                       90
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 64               86           76                 80
# 1                 72               92           86                 78
# 2                 83               82           53                 59
# 3                 80               90           78                 81
# 4                 78               84           75                 72
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  87                  86                     75
# 1                  91                  91                     74
# 2                  66                  83                     73
# 3                  83                  92                     85
# 4                  88                  85                     75
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     75                74                  91
# 1                     74                83                  84
# 2                     72                56                  91
# 3                     83                91                  89
# 4                     73                73                  91
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                77                81             77             92
# 1                69                77             74             84
# 2                75                86             62             74
# 3                78                72             54             80
# 4                73                80             69             77
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              81                89                    84
# 1              73                71                    35
# 2              94                83                    68
# 3              68                67                    60
# 4              73                82                    76
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       90                     90                86
# 1                       45                     84                86
# 2                       35                     91                71
# 3                       52                     84                91
# 4                       86                     86                88
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                   82                  NaN                           76
# 1                   84                  NaN                           42
# 2                   86                  NaN                           39
# 3                   85                  NaN                           51
# 4                   82                  NaN                           68
#
#    defending_standing_tackle  defending_sliding_tackle
# 0                         86                        79
# 1                         44                        46
# 2                         28                        27
# 3                         56                        44
# 4                         82                        77

# %%
rating16_22.shape
# Out:
# (2244, 46)

# %%
len(rating16_22['short_name'].unique())
# Out:
# 735

# %%
len(rating16_22['long_name'].unique())
# Out:
# 721

# %%
rating16_22_avg = rating16_22.groupby(by = ['short_name', 'long_name'], as_index = False).mean()

# %%
duplicateRows = rating16_22_avg[rating16_22_avg.short_name.duplicated(keep = False)]
duplicateRows
# Out:
#               short_name                      long_name  overall   age  \
# 54  A. Stolsmo Hegerberg  Ada Martine Stolsmo Hegerberg     88.0  20.0
# 55  A. Stolsmo Hegerberg      Andrine Stolsmo Hegerberg     73.0  23.5
#
#     height  weight  skill_moves  pace  shooting  passing  dribbling  \
# 54   177.0    70.0          4.0  82.0      86.0     73.0       85.0
# 55   168.0    60.0          3.0  69.0      62.0     66.5       71.5
#
#     defending  physic  attacking_crossing  attacking_finishing  \
# 54       24.0    73.0                68.0                 93.0
# 55       66.0    63.0                52.5                 68.0
#
#     attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 54                        88.0                     77.0               81.0
# 55                        48.0                     78.0               32.0
#
#     skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 54             89.0         75.0               74.0                67.0
# 55             70.0         40.0               33.0                73.0
#
#     skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 54                86.0                   79.0                   85.0
# 55                75.0                   69.5                   69.0
#
#     movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 54              64.0                83.0              76.0              75.0
# 55              67.0                74.0              68.0              49.0
#
#     power_jumping  power_stamina  power_strength  power_long_shots  \
# 54           81.0           72.0            78.0              82.0
# 55           62.0           72.0            57.0              74.0
#
#     mentality_aggression  mentality_interceptions  mentality_positioning  \
# 54                  59.0                     23.0                   89.0
# 55                  67.0                     66.0                   61.0
#
#     mentality_vision  mentality_penalties  mentality_composure  \
# 54              74.0                 82.0                 83.0
# 55              69.0                 46.0                 58.0
#
#     defending_marking_awareness  defending_standing_tackle  \
# 54                         14.0                       16.0
# 55                         61.0                       73.0
#
#     defending_sliding_tackle
# 54                      15.0
# 55                      76.0

# %%
rating16_22_avg.shape
# Out:
# (736, 42)

# %%
duplicateRows = rating16_22_avg[rating16_22_avg.long_name.duplicated(keep = False)]
duplicateRows
# Out:
#         short_name               long_name  overall   age  height  weight  \
# 94         Beatriz  Beatriz Zaneratto João     72.5  21.5   175.0    69.0
# 98   Bia Zaneratto  Beatriz Zaneratto João     72.0  23.0   176.0    69.0
# ..             ...                     ...      ...   ...     ...     ...
# 692    V. Bøe Risa          Vilde Bøe Risa     72.0  23.0   165.0    67.0
# 701        V. Risa          Vilde Bøe Risa     74.5  24.5   164.0    67.0
#
#      skill_moves  pace  shooting  passing  dribbling  defending  physic  \
# 94           2.0  60.0      49.5     56.5       66.0       58.5    78.0
# 98           2.0  60.0      64.0     66.0       73.0       44.0    77.0
# ..           ...   ...       ...      ...        ...        ...     ...
# 692          3.0  69.0      67.0     73.0       71.0       62.0    57.0
# 701          3.0  69.0      68.5     75.0       74.5       63.5    64.5
#
#      attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 94                 42.5                 45.0                        65.5
# 98                 56.0                 65.0                        58.0
# ..                  ...                  ...                         ...
# 692                71.0                 65.0                        43.0
# 701                71.0                 66.0                        43.0
#
#      attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 94                      69.0               46.5             65.5         33.0
# 98                      74.0               54.0             75.0         33.0
# ..                       ...                ...              ...          ...
# 692                     76.0               50.0             71.0         68.0
# 701                     79.0               60.0             75.0         68.0
#
#      skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 94                38.0                64.0                69.5
# 98                38.0                66.0                77.0
# ..                 ...                 ...                 ...
# 692               61.0                73.0                72.0
# 701               61.0                76.0                77.0
#
#      movement_acceleration  movement_sprint_speed  movement_agility  \
# 94                    54.0                   64.0              60.0
# 98                    54.0                   64.0              60.0
# ..                     ...                    ...               ...
# 692                   70.0                   68.0              65.0
# 701                   70.0                   68.0              65.0
#
#      movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 94                 69.5              55.0              59.0           68.0
# 98                 74.0              55.0              69.0           68.0
# ..                  ...               ...               ...            ...
# 692                64.0              78.0              75.0           52.0
# 701                68.0              78.0              75.0           61.0
#
#      power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 94            72.5            81.5              48.5                  78.0
# 98            75.0            80.0              60.0                  74.0
# ..             ...             ...               ...                   ...
# 692           72.0            55.0              72.0                  45.0
# 701           78.5            65.0              74.5                  45.0
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 94                      57.5                   52.5              52.5
# 98                      42.0                   73.0              75.0
# ..                       ...                    ...               ...
# 692                     59.0                   63.0              72.0
# 701                     63.5                   68.0              76.5
#
#      mentality_penalties  mentality_composure  defending_marking_awareness  \
# 94                  60.0                 69.0                         53.5
# 98                  60.0                 70.0                         35.0
# ..                   ...                  ...                          ...
# 692                 49.0                 72.0                         66.0
# 701                 49.0                 71.5                         66.0
#
#      defending_standing_tackle  defending_sliding_tackle
# 94                        61.5                      60.0
# 98                        50.0                      46.0
# ..                         ...                       ...
# 692                       69.0                      58.0
# 701                       69.5                      58.5
#
# [29 rows x 42 columns]

# %%
rating16_22_avg = rating16_22.groupby(by = ['long_name'], as_index = False).mean()

# %%
rating16_22_avg.shape
# Out:
# (721, 41)

# %%
add_nation = rating16_22[['long_name','nationality']].drop_duplicates('long_name')

# %%
rating16_22_new = pd.merge(rating16_22_avg, add_nation, on = 'long_name', how = 'left')

# %%
rating16_22_new.head()
# Out:
#                        long_name    overall   age      height  weight  \
# 0             Abbie Mary McManus  77.000000  26.0  171.666667    68.0
# 1                 Abby May Erceg  84.333333  30.0  177.000000    68.0
# 2                   Abby Wambach  90.000000  35.0  180.000000    81.0
# 3        Abigail Lynn Dahlkemper  80.750000  26.5  170.000000    54.0
# 4  Ada Martine Stolsmo Hegerberg  88.000000  20.0  177.000000    70.0
#
#    skill_moves       pace   shooting    passing  dribbling  defending  \
# 0          2.0  70.000000  28.333333  48.333333  56.333333       78.0
# 1          2.0  60.333333  51.000000  62.666667  65.666667       86.0
# 2          3.0  72.000000  89.000000  65.000000  80.000000       39.0
# 3          2.0  70.250000  48.750000  73.500000  67.250000       82.5
# 4          4.0  82.000000  86.000000  73.000000  85.000000       24.0
#
#       physic  attacking_crossing  attacking_finishing  \
# 0  74.333333           39.333333            26.333333
# 1  81.000000           46.000000            64.000000
# 2  82.000000           53.000000            93.000000
# 3  80.250000           72.500000            45.500000
# 4  73.000000           68.000000            93.000000
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                   74.333333                67.333333          29.333333
# 1                   83.000000                76.333333          18.000000
# 2                   91.000000                71.000000          83.000000
# 3                   75.250000                76.500000          37.500000
# 4                   88.000000                77.000000          81.000000
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0        43.333333    38.333333          37.333333           50.333333
# 1        60.333333    45.000000          47.000000           69.333333
# 2        82.000000    53.000000          59.000000           66.000000
# 3        67.500000    53.500000          56.500000           80.500000
# 4        89.000000    75.000000          74.000000           67.000000
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0           69.333333              67.333333              71.666667
# 1           71.666667              56.666667              64.000000
# 2           83.000000              73.000000              72.000000
# 3           63.000000              67.500000              73.000000
# 4           86.000000              79.000000              85.000000
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0         65.333333           79.666667         64.333333         34.333333
# 1         58.000000           84.000000         78.000000         45.000000
# 2         56.000000           91.000000         75.000000         86.000000
# 3         55.500000           85.500000         90.000000         52.500000
# 4         64.000000           83.000000         76.000000         75.000000
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0      77.333333      69.333333       76.333333         22.333333
# 1      78.000000      76.000000       83.000000         42.000000
# 2      62.000000      74.000000       94.000000         83.000000
# 3      75.000000      85.500000       78.500000         45.500000
# 4      81.000000      72.000000       78.000000         82.000000
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0             75.333333                78.666667              27.333333
# 1             82.000000                84.000000              35.000000
# 2             68.000000                35.000000              91.000000
# 3             78.500000                84.250000              69.750000
# 4             59.000000                23.000000              89.000000
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0         25.333333            48.333333            62.666667
# 1         57.000000            50.000000            82.000000
# 2         71.000000            86.000000                  NaN
# 3         72.500000            69.500000            73.500000
# 4         74.000000            82.000000            83.000000
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                         79.0                  79.333333
# 1                         89.0                  87.000000
# 2                         39.0                  28.000000
# 3                         84.5                  82.500000
# 4                         14.0                  16.000000
#
#    defending_sliding_tackle    nationality
# 0                 72.666667        England
# 1                 85.000000    New Zealand
# 2                 27.000000  United States
# 3                 79.750000  United States
# 4                 15.000000         Norway

# %%
rating16_22_new.shape
# Out:
# (721, 42)

# %%
def get_strip(df, attr, figsize = (10,5), size = 2):
    means = df.groupby(['nationality'])[attr].mean().sort_values()
    plt.subplots(figsize=figsize)
    sns.stripplot(x='nationality', y= attr, data=df, order = means.index, palette = 'crest', size = size)
    sns.set_style('whitegrid')
    sns.set_context('paper', font_scale = 1)
    plt.xticks(rotation='vertical')
    plt.ylabel(attr)
    plt.xlabel('Country')

# %%
get_strip(rating16_22_new, 'overall')
plt.savefig('../imgs/FIFA_16-22/overall_rating.pdf',bbox_inches='tight')

# %%
#get_strip(rating16_22_new, 'pace')
#plt.savefig('../imgs/FIFA_16-22/pace.png',bbox_inches='tight')

# %%
#get_strip(rating16_22_new, 'shooting')
#plt.savefig('../imgs/FIFA_16-22/shooting.png',bbox_inches='tight')

# %%
#get_strip(rating16_22_new, 'passing')
#plt.savefig('../imgs/FIFA_16-22/passing.png',bbox_inches='tight')

# %%
#get_strip(rating16_22_new, 'defending')
#plt.savefig('../imgs/FIFA_16-22/defending.png',bbox_inches='tight')

# %%
#get_strip(rating16_22_new, 'dribbling')
#plt.savefig('../imgs/FIFA_16-22/dribbling.png',bbox_inches='tight')

# %%
rating23 = pd.read_csv('../Datasets/cleaned_data/FIFA23_rating_combined.csv')

# %%
rating23.head()
# Out:
#                   full_name nationality  birthyear position  height  weight  \
# 0    Alexia Putellas Segura       Spain       1994       CM     173      67
# 1    Caroline Graham Hansen      Norway       1995       RW     178      66
# 2  Maria Pilar Leon Cebrian       Spain       1995       CB     169      61
# 3   Irene Paredes Hernandez       Spain       1991       CB     177      62
# 4       Sandra Panos Garcia       Spain       1992       GK     169      65
#
#    overall  pace  shooting  passing  dribbling  defending  phy  longshots  \
# 0       92    80        90       92         91         72   75         90
# 1       90    88        84       90         91         48   75         85
# 2       88    78        58       80         77         91   78         59
# 3       88    75        54       68         70         90   84         55
# 4       88    87        84       87         91         46   87         17
#
#    volleys  balance  shotpower  longpassing  standingtackle  crossing  curve  \
# 0       90       78         81           91              82        87     89
# 1       82       75         79           84              50        93     90
# 2       49       75         51           90              90        86     63
# 3       60       65         60           62              87        59     69
# 4       19       70         65           18              18        16     22
#
#    finishing  slidingtackle  aggression  sprintspeed  headingaccuracy  \
# 0         94             64          58           78               74
# 1         86             46          66           88               75
# 2         61             90          88           79               87
# 3         51             87          87           75               88
# 4         11             14          19           50               20
#
#    reactions  ranking  penalties  strength  skillmoves  stamina  ballcontrol  \
# 0         95        1         91        75           5       90           94
# 1         89        8         80        74           5       84           92
# 2         94       13         64        75           2       75           91
# 3         92       14         70        82           2       85           85
# 4         84       17         27        64           1       45           20
#
#    acceleration  preferredfoot  vision  agility  composure  jumping  \
# 0            82              2      95       76         91       75
# 1            88              1      93       85         84       68
# 2            77              2      56       75         70       76
# 3            75              1      51       68         75       79
# 4            44              1      34       54         56       72
#
#    interceptions  shortpassing
# 0             79            95
# 1             35            90
# 2             91            90
# 3             92            84
# 4             19            23

# %%
len(rating23.nationality.unique())
# Out:
# 46

# %%
nation_list = rating23.nationality.unique()

# %%
nation_list
# Out:
# array(['Spain', 'Norway', 'United States', 'Germany', 'Sweden',
#        'Slovakia', 'Switzerland', 'Czech', 'Iceland', 'France', 'Canada',
#        'Cameroon', 'England', 'Argentina', 'Ireland', 'Wales', 'Holland',
#        'Australia', 'Denmark', 'Portugal', 'Scotland', 'China', 'Nigeria',
#        'Mexico', 'Belgium', 'Poland', 'Brazil', 'Chile', 'Austria',
#        'Italy', 'Japan', 'Slovenia', 'Costa', 'Venezuela', 'New Zealand',
#        'Jamaica', 'Finland', 'Bosnia', 'Serbia', 'Haiti', 'Côte', 'Korea',
#        'Morocco', 'Greece', 'Mali', 'Russia'], dtype=object)

# %%
nation_map = {'United':'United States', 'Republic':'Ireland', 'New':'New Zealand'}

# %%
rating23['nationality'] = rating23['nationality'].replace(nation_map)

# %%
rating23.shape
# Out:
# (700, 41)

# %%
rating23.head()
# Out:
#                   full_name nationality  birthyear position  height  weight  \
# 0    Alexia Putellas Segura       Spain       1994       CM     173      67
# 1    Caroline Graham Hansen      Norway       1995       RW     178      66
# 2  Maria Pilar Leon Cebrian       Spain       1995       CB     169      61
# 3   Irene Paredes Hernandez       Spain       1991       CB     177      62
# 4       Sandra Panos Garcia       Spain       1992       GK     169      65
#
#    overall  pace  shooting  passing  dribbling  defending  phy  longshots  \
# 0       92    80        90       92         91         72   75         90
# 1       90    88        84       90         91         48   75         85
# 2       88    78        58       80         77         91   78         59
# 3       88    75        54       68         70         90   84         55
# 4       88    87        84       87         91         46   87         17
#
#    volleys  balance  shotpower  longpassing  standingtackle  crossing  curve  \
# 0       90       78         81           91              82        87     89
# 1       82       75         79           84              50        93     90
# 2       49       75         51           90              90        86     63
# 3       60       65         60           62              87        59     69
# 4       19       70         65           18              18        16     22
#
#    finishing  slidingtackle  aggression  sprintspeed  headingaccuracy  \
# 0         94             64          58           78               74
# 1         86             46          66           88               75
# 2         61             90          88           79               87
# 3         51             87          87           75               88
# 4         11             14          19           50               20
#
#    reactions  ranking  penalties  strength  skillmoves  stamina  ballcontrol  \
# 0         95        1         91        75           5       90           94
# 1         89        8         80        74           5       84           92
# 2         94       13         64        75           2       75           91
# 3         92       14         70        82           2       85           85
# 4         84       17         27        64           1       45           20
#
#    acceleration  preferredfoot  vision  agility  composure  jumping  \
# 0            82              2      95       76         91       75
# 1            88              1      93       85         84       68
# 2            77              2      56       75         70       76
# 3            75              1      51       68         75       79
# 4            44              1      34       54         56       72
#
#    interceptions  shortpassing
# 0             79            95
# 1             35            90
# 2             91            90
# 3             92            84
# 4             19            23

# %%
rating23.isna().sum()
# Out:
# full_name        0
# nationality      0
#                 ..
# interceptions    0
# shortpassing     0
# Length: 41, dtype: int64

# %%
nation_count = rating23.nationality.value_counts()

# %%
keys = nation_count.loc[nation_count >10].index

# %%
rating23_to_plot= rating23[rating23['nationality'].isin(keys)]

# %%
get_strip(rating23_to_plot, 'overall', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/overall_rating.pdf',bbox_inches='tight')

# %%
get_strip(rating23_to_plot, 'pace', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/pace.pdf',bbox_inches='tight')

# %%
get_strip(rating23_to_plot, 'shooting', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/shooting.pdf',bbox_inches='tight')

# %%
get_strip(rating23_to_plot, 'passing', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/passing.pdf',bbox_inches='tight')

# %%
get_strip(rating23_to_plot, 'dribbling', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/dribbling.pdf',bbox_inches='tight')

# %%
get_strip(rating23_to_plot, 'defending', figsize = (12,4))
plt.savefig('../imgs/FIFA_23/defending.pdf',bbox_inches='tight')
