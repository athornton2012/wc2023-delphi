# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
r = requests.get('https://fbref.com/en/matches/c358061f/United-States-Netherlands-July-7-2019-FIFA-Womens-World-Cup')
soup = BeautifulSoup(r.content, 'html.parser')
table = soup.find_all('table', class_ = 'stats_table sortable')
df = pd.read_html(str(table[i]))[0]

# %%
dict = {}

# %%
dict['dd']= pd.read_html(str(table[0]))[0]

# %%
dict['dd']
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                Player                  #                Pos
# 0         Alex Morgan               13.0              FW,RW
# 1       Megan Rapinoe               15.0                 LW
# 2      Christen Press               23.0                 LW
# 3         Tobin Heath               17.0                 RW
# 4         Carli Lloyd               10.0                 FW
# 5           Sam Mewis                3.0              LM,CM
# 6          Julie Ertz                8.0              CM,CB
# 7        Rose Lavelle               16.0              RM,CM
# 8        Crystal Dunn               19.0              LB,LM
# 9    Becky Sauerbrunn                4.0                 CB
# 10    Abby Dahlkemper                7.0                 CB
# 11      Kelley O'Hara                5.0                 RB
# 12        Ali Krieger               11.0              RB,RM
# 13      Alyssa Naeher                1.0                 GK
# ...

# %%
r = requests.get('https://fbref.com/en/matches/c358061f/United-States-Netherlands-July-7-2019-FIFA-Womens-World-Cup')
soup = BeautifulSoup(r.content, 'html.parser')

# %%
texts = soup.find_all('div', class_ = 'table_wrapper tabbed')

# %%
texts
# Out:
# [<div class="table_wrapper tabbed" id="all_player_stats_1c912aa0">
#  <span class="section_anchor" data-label="USA Player Stats" id="player_stats_1c912aa0_link"></span>
#  <div class="section_heading assoc_stats_1c912aa0_summary" id="stats_1c912aa0_summary_sh">
#  <span class="section_anchor" data-label="USA Player Stats" data-no-inpage="1" id="stats_1c912aa0_summary_link"></span><h2>USA Player Stats</h2> <div class="section_heading_text">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <div class="section_heading hidden assoc_stats_1c912aa0_passing" id="stats_1c912aa0_passing_sh">
#  <span class="section_anchor" data-label="USA Player Stats" data-no-inpage="1" id="stats_1c912aa0_passing_link"></span><h2>USA Player Stats</h2> <div class="section_heading_text">
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <div class="section_heading hidden assoc_stats_1c912aa0_passing_types" id="stats_1c912aa0_passing_types_sh">
# ...

# %%
table = soup.find_all('table', class_ = 'stats_table sortable')

# %%
table
# Out:
# [<table class="stats_table sortable" data-cols-to-freeze=",1" id="stats_1c912aa0_summary"> <caption>USA Player Stats Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="12" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_sca">SCA</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_passes">Passes</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_carries">Carries</th> <th aria
# ...

# %%
table[0]
# Out:
# <table class="stats_table sortable" data-cols-to-freeze=",1" id="stats_1c912aa0_summary"> <caption>USA Player Stats Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="12" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_sca">SCA</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_passes">Passes</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_carries">Carries</th> <th aria-
# ...

# %%
x = table2.get_text()

# %%
df = pd.DataFrame([x.split(';') for x in data.split('\n')])
# Out:
# 12

# %%
df = pd.read_html(str(table[7]))[0]

# %%
table[1]
# Out:
# <table class="stats_table sortable" data-cols-to-freeze=",1" id="stats_1c912aa0_passing"> <caption>USA Player Stats Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_passes_total">Total</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_short">Short</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_medium">Medium</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_long">Long</th><th></th> <th aria-label="" class="over_header center" colspan="7" data-stat=""></th> </tr> <tr> <th aria-label="Player" class
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
table[0].select('caption')[0].text
# Out:
# 'USA Player Stats Table'
