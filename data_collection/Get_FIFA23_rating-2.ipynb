# %%
import requests
import pandas as pd
import json
import time

# %%
url = 'https://ratings-api.ea.com/v2/entities/fifa-23-womens-rating?sort=ranking%3AASC&limit=1200'

r = requests.get(url)

json_data = json.loads(r.text)

data_docs = json_data['docs']

# %%
length = len(data_docs)

# %%
FIFA23_rating = pd.DataFrame.from_dict(data_docs)

# %%
FIFA23_rating
# Out:
#      contractvaliduntil_diff  gkdiving_diff        birthdate playerjerseyname  \
# 0                          0              0    2/4/1994 0:00           Alexia
# 1                          0              0   9/10/1993 0:00             Kerr
# 2                          0              0   7/20/1990 0:00           Renard
# 3                          0              0   7/10/1995 0:00        Hegerberg
# 4                          0              0   11/1/1998 0:00           Katoto
# ..                       ...            ...              ...              ...
# 495                        0              0  11/11/1995 0:00           Graham
# 496                        0              0   11/8/1995 0:00         Grimshaw
# 497                        0              0   1/28/1999 0:00      K.Holmgaard
# 498                        0              0   7/26/1998 0:00         Diana G.
# 499                        0              0    1/3/1995 0:00          Tarrieu
#
#      def  longshots preferredposition4label  volleys  ranking_diff  \
# 0     72         90                               90             0
# 1     42         89                               92             0
# 2     93         65                               55             0
# 3     39         89                               90             0
# 4     39         87                               91             0
# ..   ...        ...                     ...      ...           ...
# 495   51         73                               55             0
# 496   34         66                               67             0
# 497   74         53                               43             0
# 498   74         23                               29             0
# 499   40         59                               59             0
#
#      contractvaliduntil  ...  gkkicking_diff  gkreflexes_diff  potential_diff  \
# 0                  2024  ...               0                0               0
# 1                  2024  ...               0                0               0
# 2                  2026  ...               0                0               0
# 3                  2024  ...               0                0               0
# 4                  2025  ...               0                0               0
# ..                  ...  ...             ...              ...             ...
# 495                2023  ...               0                0               0
# 496                2027  ...               0                0               0
# 497                2024  ...               0                0               0
# 498                2026  ...               0                0               0
# 499                2023  ...               0                0               0
#
#      lastnameid_diff  interceptions  shortpassing  preferredposition1_diff  \
# 0                  0             79            95                        0
# 1                  0             24            78                        0
# 2                  0             90            84                        0
# 3                  0             23            84                        0
# 4                  0             27            87                        0
# ..               ...            ...           ...                      ...
# 495                0             45            79                        0
# 496                0             31            74                        0
# 497                0             71            74                        0
# 498                0             73            72                        0
# 499                0             40            73                        0
#
#      preferredposition4_diff                teamname  primaryKey
# 0                          0             Spain Women      227203
# 1                          0                 Chelsea      227125
# 2                          0      Olympique Lyonnais      227316
# 3                          0      Olympique Lyonnais      227310
# 4                          0     Paris Saint-Germain      246272
# ..                       ...                     ...         ...
# 495                        0       Tottenham Hotspur      265261
# 496                        0          Scotland Women      266603
# 497                        0                 Everton      265012
# 498                        0          Portugal Women      261853
# 499                        0  Rodez Aveyron Football      265882
#
# [500 rows x 138 columns]

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
FIFA23_rating.columns.values
# Out:
# array(['contractvaliduntil_diff', 'gkdiving_diff', 'birthdate',
#        'playerjerseyname', 'def', 'longshots', 'preferredposition4label',
#        'volleys', 'ranking_diff', 'contractvaliduntil', 'balance',
#        'shotpower', 'defensiveawareness', 'defensiveworkrate_diff',
#        'standingtackle_diff', 'acceleration_diff', 'height',
#        'strength_diff', 'freekickaccuracy_diff', 'dribbling_diff',
#        'ballcontrol_diff', 'longpassing', 'standingtackle', 'crossing',
#        'sprintspeed_diff', 'nationality', 'nationality_diff',
#        'positioning_diff', 'status', 'attackingworkrate_diff', 'gender',
#        'curve', 'aggression_diff', 'teamid_diff', 'gkpositioning_diff',
#        'slidingtackle', 'stamina_diff', 'gkreflexes',
#        'preferredposition3_diff', 'finishing', 'commonname', 'surname',
#        'agility_diff', 'lastnameid', 'preferredposition2_diff',
#        'leaguename', 'longshots_diff', 'preferredposition3label',
#        'vision_diff', 'aggression', 'height_diff', 'gkpositioning',
#        'gkhandling_diff', 'sprintspeed', 'interceptions_diff',
#        'headingaccuracy', 'fullNameForSearch', 'reactions',
#        'weakfootabilitytypecode_diff', 'ranking', 'overall_rating',
#        'reactions_diff', 'phy', 'commonnameid', 'curve_diff', 'penalties',
#        'strength', 'skillmoves', 'stamina', 'weakfootabilitytypecode',
#        'defensiveawareness_diff', 'ballcontrol', 'commonnameid_diff',
#        'longpassing_diff', 'primaryKey_diff', 'gkhandling',
#        'slidingtackle_diff', 'acceleration', 'pac', 'teamid', 'hasphoto',
#        'dri', 'potential', 'composure_diff', 'crossing_diff', 'pas',
#        'shortpassing_diff', 'balance_diff', 'weight', 'finishing_diff',
#        'preferredfoot', 'freekickaccuracy', 'leagueid_diff', 'vision',
#        'preferredfoot_diff', 'leagueid', 'weight_diff', 'overall_diff',
#        'sho', 'playerjerseynameid_diff', 'agility', 'shotpower_diff',
#        'firstname', 'firstnameid_diff', 'playerjerseynameid', 'composure',
#        'jumping', 'volleys_diff', 'headingaccuracy_diff', 'gkkicking',
#        'preferredposition1label', 'jumping_diff', 'penalties_diff',
#        'defensiveworkrate', 'dribbling', 'skillmoves_diff',
#        'preferredposition1', 'positioning', 'attackingworkrate',
#        'preferredposition3', 'iteration', 'preferredposition2',
#        'isfakeplayer', 'preferredposition2label', 'preferredposition4',
#        'gender_diff', 'gkdiving', 'firstnameid', 'gkkicking_diff',
#        'gkreflexes_diff', 'potential_diff', 'lastnameid_diff',
#        'interceptions', 'shortpassing', 'preferredposition1_diff',
#        'preferredposition4_diff', 'teamname', 'primaryKey'], dtype=object)
