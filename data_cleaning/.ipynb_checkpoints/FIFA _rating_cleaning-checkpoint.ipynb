# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
rating23 = pd.read_csv('../Datasets/FIFA/FIFA23_rating/player_rating.csv')
rating22 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_22.csv')
rating21 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_21.csv')
rating20 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_20.csv')
rating19 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_19.csv')
rating18 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_18.csv')
rating17 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_17.csv')
rating16 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_16.csv')

# %%
def drop_1(dataset):
    '''drop columns with more than 200 missing data or more than 200 values = 0'''
    na_s = rating23.isnull().sum()
    col_0 = (rating23 == 0).sum(axis = 0)
    drop_list = [i for i in na_s.index if na_s[i] > 200]
    for i in col_0.index:
        if col_0[i]>200:
            drop_list.append(i)
    dataset.drop(columns = drop_list, inplace = True)

# %%
drop_1(rating23)
drop_1(rating22)
drop_1(rating21)
drop_1(rating20)
drop_1(rating19)
drop_1(rating18)
drop_1(rating17)
drop_1(rating16)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
rating23.columns
# Out:
# Index(['birthdate', 'playerjerseyname', 'def', 'longshots', 'volleys',
#        'contractvaliduntil', 'balance', 'shotpower', 'defensiveawareness',
#        'height', 'longpassing', 'standingtackle', 'crossing', 'nationality',
#        'status', 'gender', 'curve', 'slidingtackle', 'gkreflexes', 'finishing',
#        'surname', 'lastnameid', 'leaguename', 'aggression', 'gkpositioning',
#        'sprintspeed', 'headingaccuracy', 'fullNameForSearch', 'reactions',
#        'ranking', 'overall_rating', 'phy', 'penalties', 'strength',
#        'skillmoves', 'stamina', 'weakfootabilitytypecode', 'ballcontrol',
#        'gkhandling', 'acceleration', 'pac', 'teamid', 'hasphoto', 'dri',
#        'potential', 'pas', 'weight', 'preferredfoot', 'freekickaccuracy',
#        'vision', 'leagueid', 'sho', 'agility', 'firstname',
#        'playerjerseynameid', 'composure', 'jumping', 'gkkicking',
#        'preferredposition1label', 'dribbling', 'preferredposition1',
#        'positioning', 'preferredposition3', 'iteration', 'preferredposition2',
#        'preferredposition4', 'gkdiving', 'firstnameid', 'interceptions',
#        'shortpassing', 'teamname', 'primaryKey'],
#       dtype='object')

# %%
new_col_1 = ['fullNameForSearch', 'birthdate', 'preferredposition1label', 'height', 'weight', 'overall_rating','pac','sho','pas','dri','def','phy', 
           'longshots', 'volleys','balance', 'shotpower', 
            'longpassing', 'standingtackle', 'crossing', 'nationality',
           'curve', 'finishing','slidingtackle','aggression','sprintspeed', 'headingaccuracy', 
           'reactions', 'ranking', 'penalties', 'strength', 'skillmoves', 'stamina', 
           'ballcontrol', 'acceleration',  'preferredfoot',
           'vision',  'agility', 'composure', 'jumping', 
           'dribbling', 'interceptions', 'shortpassing']

# %%
rating23_new = rating23[new_col_1]

# %%
rating23_new['birthdate']=rating23_new.apply(lambda x:x['birthdate'].split()[0], axis=1)

rating23_new['birthdate'] = rating23_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)

rating23_new = rating23_new.rename({'fullNameForSearch':'full_name', 'birthdate':'birthyear', 'preferredposition1label': 'position'}, axis=1)

rating23_new.head()
# Out:
# C:\Users\lorih\AppData\Local\Temp\ipykernel_60264\678401155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating23_new['birthdate']=rating23_new.apply(lambda x:x['birthdate'].split()[0], axis=1)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_60264\678401155.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating23_new['birthdate'] = rating23_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)
#                 full_name  birthyear position  height  weight  overall_rating  \
# 0  Alexia Putellas Segura       1994       CM     173      67              92
# 1                Sam Kerr       1993       ST     168      66              91
# 2           Wendie Renard       1990       CB     187      70              91
# 3           Ada Hegerberg       1995       ST     176      68              91
# 4            Marie Katoto       1998       ST     177      66              90
#
#    pac  sho  pas  dri  def  phy  longshots  volleys  balance  shotpower  \
# 0   80   90   92   91   72   75         90       90       78         81
# 1   87   91   75   90   42   83         89       92       82         91
# 2   67   72   71   72   93   87         65       55       34         85
# 3   85   91   77   87   39   77         89       90       47         86
# 4   88   90   78   86   39   74         87       91       68         86
#
#    longpassing  standingtackle  crossing  nationality  curve  finishing  \
# 0           91              82        87           45     89         94
# 1           55              39        80          195     76         93
# 2           87              94        51           18     65         70
# 3           72              33        71           36     79         94
# 4           70              35        71           18     71         93
#
#    slidingtackle  aggression  sprintspeed  headingaccuracy  reactions  \
# 0             64          58           78               74         95
# 1             35          70           85               91         93
# 2             91          88           66               96         90
# 3             29          65           86               93         93
# 4             29          44           88               92         90
#
#    ranking  penalties  strength  skillmoves  stamina  ballcontrol  \
# 0        1         91        75           5       90           94
# 1        2         79        86           4       87           92
# 2        3         75        93           2       75           85
# 3        4         86        81           4       75           91
# 4        5         82        81           4       82           89
#
#    acceleration  preferredfoot  vision  agility  composure  jumping  \
# 0            82              2      95       76         91       75
# 1            89              1      83       90         92       91
# 2            68              1      59       53         84       86
# 3            83              1      76       74         86       89
# 4            89              1      79       80         85       86
#
#    dribbling  interceptions  shortpassing
# 0         93             79            95
# 1         90             24            78
# 2         69             90            84
# 3         91             23            84
# 4         86             27            87

# %%
rating22.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id',
#        'club_name', 'league_name', 'league_level', 'club_position',
#        'club_jersey_number', 'club_loaned_from', 'club_joined',
#        'club_contract_valid_until', 'nationality_id', 'nationality_name',
#        'nation_team_id', 'nation_position', 'nation_jersey_number',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'player_traits', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina',
#        'power_strength', 'power_long_shots', 'mentality_aggression',
#        'mentality_interceptions', 'mentality_positioning',
#        'mentality_vision', 'mentality_penalties', 'mentality_composure',
#        'defending_marking_awareness', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes',
#        'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf',
#        'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk',
#        'player_face_url', 'club_logo_url', 'club_flag_url',
#        'nation_logo_url', 'nation_flag_url'], dtype=object)

# %%
new_col_2 = ['short_name', 'long_name',
       'player_positions', 'overall', 'age', 'height_cm', 'weight_kg','nation_position',
       'preferred_foot',  'skill_moves', 'pace',
       'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'movement_reactions', 'movement_balance',
       'power_shot_power', 'power_jumping', 'power_stamina',
       'power_strength', 'power_long_shots', 'mentality_aggression',
       'mentality_interceptions', 'mentality_positioning',
       'mentality_vision', 'mentality_penalties', 'mentality_composure',
       'defending_marking_awareness', 'defending_standing_tackle',
       'defending_sliding_tackle']

# %%
rating22_new = rating22[new_col_2]
rating21_new = rating21[new_col_2]
rating20_new = rating20[new_col_2]
rating19_new = rating19[new_col_2]
rating18_new = rating18[new_col_2]
rating17_new = rating17[new_col_2]
rating16_new = rating16[new_col_2]

# %%
rating23_new.to_csv('../Datasets/cleaned_data/FIFA23_rating_new.csv', index = False)

# %%
rating22_new.head(5)
# Out:
#    short_name                   long_name player_positions  overall  age  \
# 0   L. Bronze  Lucia Roberta Tough Bronze           RB, CM       92   29
# 1   W. Renard   Wéndèleine Thérèse Renard               CB       92   30
# 2  V. Miedema            Vivianne Miedema               ST       92   24
# 3     S. Kerr           Samantha May Kerr           ST, LW       91   27
# 4   A. Morgan   Alexandra Morgan Carrasco               ST       90   31
#
#    height_cm  weight_kg nation_position preferred_foot  skill_moves  pace  \
# 0        171         67              RB          Right            3  86.0
# 1        187         70             LCB          Right            2  68.0
# 2        178         65              ST          Right            4  81.0
# 3        167         55              ST          Right            4  87.0
# 4        170         62              ST           Left            4  86.0
#
#    shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 0      61.0     70.0       81.0       89.0    84.0                  78
# 1      70.0     62.0       73.0       91.0    88.0                  25
# 2      93.0     75.0       88.0       32.0    79.0                  69
# 3      90.0     72.0       91.0       39.0    80.0                  74
# 4      88.0     74.0       86.0       43.0    71.0                  71
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   60                          88                       84
# 1                   70                          94                       83
# 2                   95                          89                       87
# 3                   94                          92                       79
# 4                   90                          86                       81
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 35               79           39                 45
# 1                 41               69           49                 58
# 2                 90               90           76                 71
# 3                 82               90           76                 63
# 4                 88               87           68                 70
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  63                  85                     87
# 1                  78                  85                     69
# 2                  67                  91                     80
# 3                  70                  94                     89
# 4                  67                  89                     85
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     86                73                  93
# 1                     67                56                  84
# 2                     81                77                  92
# 3                     85                93                  90
# 4                     86                76                  83
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                82                69             84             94
# 1                44                85             94             77
# 2                73                91             73             79
# 3                82                92             89             87
# 4                68                86             76             75
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              82                65                    78
# 1              93                63                    88
# 2              85                92                    66
# 3              78                86                    75
# 4              76                83                    53
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       89                     57                58
# 1                       88                     70                55
# 2                       27                     95                68
# 3                       24                     95                61
# 4                       63                     90                74
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                   53                   80                           90
# 1                   60                   80                           90
# 2                   78                   91                           22
# 3                   72                   92                           36
# 4                   89                   91                           34
#
#    defending_standing_tackle  defending_sliding_tackle
# 0                         88                        89
# 1                         93                        91
# 2                         30                        23
# 3                         38                        23
# 4                         29                        27

# %%
'Morgan' in rating22_new['short_name'].values
# Out:
# False

# %%
'Morgan' in 'A. Morgan'
# Out:
# True

# %%
# Out:
# array(['L. Bronze', 'W. Renard', 'V. Miedema', 'S. Kerr', 'A. Morgan',
#        'D. Marozsán', 'M. Rapinoe', 'T. Heath', 'C. Hansen', 'A. Henry',
#        'J. Ertz', 'C. Sinclair', 'E. Le Sommer', 'L. Martens',
#        'B. Sauerbrunn', 'A. Popp', 'F. Kirby', 'Jenni Hermoso',
#        'S. Däbritz', 'A. Majri', 'L. Horan', 'K. Little', 'C. Press',
#        'A. Naeher', 'C. Dunn', 'S. Mewis', 'N. Fischer', 'C. Seger',
#        'S. Bouhaddi', "K. O'Hara", 'S. Houghton', 'M. Eriksson',
#        'Alexia Putellas', 'R. Lavelle', 'J. Groenen', 'I. Engen',
#        'A. Harris', 'K. Asllani', 'L. Benkarth', 'S. Huth', 'K. Buchanan',
#        'D. Cascarino', 'A. Erceg', 'S. Blackstenius', 'D. van de Donk',
#        'L. Magull', 'G. Gwinn', 'L. Oberdorf', 'S. Jakobsson',
#        'H. Lindahl', 'F. Rolfö', 'Irene Paredes', 'J. Nobbs', 'M. Mjelde',
#        'G. Mbock', 'K. Diani', 'S. Schmidt', 'K. Robles', 'M. Pugh',
#        'A. Franch', 'S. Spitse', 'N. Parris', 'Miri Couto',
#        'Emanuelly Barni', 'M. Katoto', 'A. Krieger', 'M. Leupolz',
#        'K. Hendrich', 'Wu Haiyan', 'C. Foord', 'S. Catley', 'E. White',
#        'K. Minde', 'L. Maier', 'G. Reiten', 'A. Lawrence', 'D. Scott',
#        'S. van Veenendaal', 'A. Dahlkemper', 'M. Bright', 'L. Dallmann',
#        'E. Carpenter', 'J. Roord', 'Jully Mutto', 'Palomy Bastos',
#        'M. Frohms', 'K. Bühl', 'A. Berger', 'E. Haavi', 'L. Williams',
#        'Sandra Paños', 'Mapi León', 'H. Glas', 'L. Schüller',
#        'Letinha Lia', 'Isinha Macapá', 'Becky Saudera', 'S. Lohmann',
#        'M. Hegering', 'T. Wullaert', 'Wang Shuang', 'Tang Jiali',
#        'E. Kellond-Knight', 'K. Bardsley', 'A. Greenwood', 'J. Scott',
#        'C. Telford', 'J. Beckie', 'S. Labbé', 'M. Torrent', 'E. Sonnett',
#        'A. Riley', 'S. van der Gragt', 'F. Rauch', 'R. Daly', 'G. Geyoro',
#        'K. Sheridan', 'L. Beerensteyn', 'Peng Shimeng', 'Julininha Ruiz',
#        'Karole Pombal', 'L. Freigang', 'J. Cayman', 'Liu Shanshan',
#        'E. van Egmond', 'H. Raso', 'D. Stokes', 'S. Mayor', 'R. Percival',
#        'S. van de Sanden', 'D. Janssen', 'E. Perisset', 'K. Walsh',
#        'C. Emslie', 'Bianca Revelia', 'Becky Redela', 'J. Beattie',
#        'C. Weir', 'T. De Caigny', 'Li Ying', 'Ma Jun', 'A. Ilestedt',
#        'A. Kennedy', 'K. Gorry', 'Marta Corredera', 'J. Fleming',
#        'Amanda Sampedro', 'E. Nayler', 'S. Karchaoui', 'M. van Dongen',
#        'A. Dekker', 'Patri Guijarro', 'Z. Mušović', 'G. Stanway',
#        'B. Mead', 'E. Cuthbert', 'L. Williamson', 'Wang Shanshan',
#        'Zhang Xin', 'O. Schough', 'E. Rubensson', 'C. Polkinghorne',
#        'T. Yallop', 'Virginia Torrecilla', 'Vicky Losada',
#        'C. Fiskerstrand', 'E. McLeod', 'K. Bowen', 'J. Andersson',
#        'C. Krueger', 'Mariona', 'Aitana Bonmatí', 'V. Risa', 'Lin Yuping',
#        'Melinda Goiás', 'E. Mitchell', 'L. Evans', 'A. Nouwen',
#        'N. Björn', 'E. Roebuck', 'B. England', 'Zhai Qingwei',
#        'Cláudia Neto', 'Zhang Rui', 'Gu Yasha', 'V. Asseyi', 'K. Dali',
#        'A. Chapman', 'Leila Ouahabi', 'K. van Es', 'S. Zadorsky',
#        'A. Tounkara', 'T. Knaak', 'Cecil Sendela', 'Zoe Tocantins',
#        'Isaby Camila', 'Niccole Cintra', 'K. Sævik', 'L. Alexander',
#        'R. Corsie', 'J. Falk', 'A. Anvegård', 'Li Mengwen', 'J. Brand',
#        'J. Biesmans', 'Carole Costa', 'Ana Borges', 'Yang Li', 'Han Peng',
#        'Quinn', 'Ivana Andrés', 'M. Arnold', 'E. Alvarado',
#        'Pang Fengyue', 'C. Logarzo', 'Andrea Pereira', 'Esther González',
#        'L. Utland', 'M. Moore', 'A. Longo', 'I. Kaagman', 'N. Prince',
#        'F. Maanum', 'R. Jansen', 'S. Durand', 'Lucía García',
#        'K. Snoeijs', 'Iris Vieirinha', 'Jandinha Kenedy', 'S. Howard',
#        'F. Brown', 'K. Smith', 'Nahikari', 'M. Janogy', 'V. Gilles',
#        'Ona Batlle', 'C. Kelly', 'L. Hemp', 'Yao Lingwei', 'L. Deloose',
#        'D. Philtjens', 'Dolores Silva', 'Sílvia Rebelo', 'C. Macario',
#        'F. Angeldahl', 'L. Hurtig', 'K. Simon', 'A. Leon', 'C. Bilbault',
#        'M. Thorisdottir', 'L. Geurts', 'M. Purce', 'Kla Elisinha',
#        'Giovanny Bia', 'Magi Bardini', 'J. Ross', 'L. Clelland',
#        'C. Murray', 'J. Love', 'H. Lauder', 'P. Peyraud-Magnin',
#        'Alba Redondo', 'L. Wilms', 'Marta Cardona', 'S. Kleinherne',
#        'Misa', 'A. Cervantes', 'K. Missipo', 'Jéssica Silva', 'S. Jensen',
#        'M. Sánchez', 'R. White', 'D. Kerkdijk', 'V. Esson', 'K. Leine',
#        'O. Chance', 'Rafaelly Paraná', 'L. Arnot', 'C. Arthur',
#        'L. Crichton', 'E. Laurent', 'N. Docherty', 'D. Espinosa',
#        'J. Huitema', 'Yao Wei', 'Laia Aleixandri', 'P. Morroni',
#        'J. López', 'É. Viens', 'J. Vanhaevermaet', 'L. De Neve',
#        'M. Minnaert', 'L. Onzia', 'Patrícia Morais', 'Carolina Mendes',
#        'E. Toone', 'H. Bennison', 'Li Jiayue', 'E. Thorsnes',
#        'C. Jaramillo', 'Bi Xiaolin', 'E. Gielnik', 'S. Hansen',
#        'A. Green', 'H. Wilkinson', 'C. Bott', 'L. Agnew', 'D. Rose',
#        'S. Woeller', 'R. Bernal', 'L. Kop', 'V. Pelova',
#        'Licinha Bardini', 'A. Eikeland', 'J. Roddar', 'A. González',
#        'J. Odeurs', 'N. Evrard', 'D. Vanmechelen', 'C. Vande Velde',
#        'Tatiana Pinto', 'Diana Silva', 'Andreia Norton', 'Fátima Pinto',
#        'K. Cooney-Cross', 'A. Cook', 'Song Duan', 'N. Antonio',
#        'B. Hassett', 'T. Hansen', 'K. Rood', 'M. Kelly', 'J. Fife',
#        'L. Staniforth', 'Luo Guiping', 'É. De Almeida', 'I. González',
#        'Joana Marchão', 'Ana Capeta', 'Inês Pereira', 'J. Montoya',
#        'J. Orejel', 'S. Lynn', 'C. Kvamme', 'E. Kullberg', 'S. Van Belle',
#        'A. Tysiak', 'C. Tison', 'Telma Encarnação', 'Kika Nazareth',
#        'Rute Costa', 'A. Harrison', 'C. Ferral', 'B. Campos', 'T. Åsland',
#        'M. Fowler', 'D. Evangelista', 'M. Cadena', 'E. Cascarino',
#        'L. Wajnblum', 'Andreia Jacinto', 'Andreia Faria',
#        'Alícia Correia', 'K. Rodríguez', 'S. Smith', 'A. Rodríguez',
#        'A. Phillips', 'P. Satchell', 'J. Hellstrom', 'K. Roestbakken',
#        'C. Bunge', 'G. Pettersen', 'M. Villeda', 'I. Iliano', 'D. Lemey',
#        'M. Coutereels', 'Catarina Amado', 'S. Morton', 'A. Mikalsen',
#        'N. Stratford', 'J. Blakstad', 'M. Delgadillo', 'S. Skilton',
#        'T. Micah', 'D. García', 'M. van der Meer', 'H. Eurlings',
#        'Ana Dias', 'G. Rennie', 'C. Nevin', 'C. Grant'], dtype=object)
