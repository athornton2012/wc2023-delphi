# %%
import numpy as np
import pandas as pd
from datetime import datetime
import requests
from bs4 import BeautifulSoup

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
rating23 = pd.read_csv('../Datasets/FIFA/FIFA23_rating_combined.csv')
rating22 = pd.read_csv('../Datasets/FIFA/FIFA22_rating_new.csv')
rating21 = pd.read_csv('../Datasets/FIFA/FIFA21_rating_new.csv')
rating20 = pd.read_csv('../Datasets/FIFA/FIFA20_rating_new.csv')
rating19 = pd.read_csv('../Datasets/FIFA/FIFA19_rating_new.csv')
#rating18 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_18.csv')
#rating17 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_17.csv')
#rating16 = pd.read_csv('../Datasets/FIFA/FIFA22_rating/female_players_16.csv')

# %%
def drop_1(dataset):
    '''drop columns with more than 200 missing data or more than 200 values = 0'''
    na_s = rating23.isnull().sum()
    col_0 = (rating23 == 0).sum(axis = 0)
    drop_list = [i for i in na_s.index if na_s[i] > 200]
    for i in col_0.index:
        if col_0[i]>200:
            drop_list.append(i)
    dataset.drop(columns = drop_list, inplace = True)

# %%
drop_1(rating23)
drop_1(rating22)
drop_1(rating21)
drop_1(rating20)
drop_1(rating19)

# %%
new_col_1 = ['fullNameForSearch', 'nationality', 'birthdate', 'preferredposition1label', 'height', 'weight', 'overall_rating','pac','sho','pas','dri','def','phy', 
           'longshots', 'volleys','balance', 'shotpower', 
            'longpassing', 'standingtackle', 'crossing',
           'curve', 'finishing','slidingtackle','aggression','sprintspeed', 'headingaccuracy', 
           'reactions', 'ranking', 'penalties', 'strength', 'skillmoves', 'stamina', 
           'ballcontrol', 'acceleration',  'preferredfoot',
           'vision',  'agility', 'composure', 'jumping', 
           'interceptions', 'shortpassing']

# %%
rating23_new = rating23.copy()
rating23_new.columns = new_col_1

# %%
rating23_new.head()
# Out:
#           fullNameForSearch nationality  birthdate preferredposition1label  \
# 0    Alexia Putellas Segura       Spain       1994                      CM
# 1    Caroline Graham Hansen      Norway       1995                      RW
# 2  Maria Pilar Leon Cebrian       Spain       1995                      CB
# 3   Irene Paredes Hernandez       Spain       1991                      CB
# 4       Sandra Panos Garcia       Spain       1992                      GK
#
#    height  weight  overall_rating  pac  sho  pas  dri  def  phy  longshots  \
# 0     173      67              92   80   90   92   91   72   75         90
# 1     178      66              90   88   84   90   91   48   75         85
# 2     169      61              88   78   58   80   77   91   78         59
# 3     177      62              88   75   54   68   70   90   84         55
# 4     169      65              88   87   84   87   91   46   87         17
#
#    volleys  balance  shotpower  longpassing  standingtackle  crossing  curve  \
# 0       90       78         81           91              82        87     89
# 1       82       75         79           84              50        93     90
# 2       49       75         51           90              90        86     63
# 3       60       65         60           62              87        59     69
# 4       19       70         65           18              18        16     22
#
#    finishing  slidingtackle  aggression  sprintspeed  headingaccuracy  \
# 0         94             64          58           78               74
# 1         86             46          66           88               75
# 2         61             90          88           79               87
# 3         51             87          87           75               88
# 4         11             14          19           50               20
#
#    reactions  ranking  penalties  strength  skillmoves  stamina  ballcontrol  \
# 0         95        1         91        75           5       90           94
# 1         89        8         80        74           5       84           92
# 2         94       13         64        75           2       75           91
# 3         92       14         70        82           2       85           85
# 4         84       17         27        64           1       45           20
#
#    acceleration  preferredfoot  vision  agility  composure  jumping  \
# 0            82              2      95       76         91       75
# 1            88              1      93       85         84       68
# 2            77              2      56       75         70       76
# 3            75              1      51       68         75       79
# 4            44              1      34       54         56       72
#
#    interceptions  shortpassing
# 0             79            95
# 1             35            90
# 2             91            90
# 3             92            84
# 4             19            23

# %%
rating23_new['birthdate']=rating23_new.apply(lambda x:x['birthdate'].split()[0], axis=1)

rating23_new['birthdate'] = rating23_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)

rating23_new = rating23_new.rename({'fullNameForSearch':'full_name', 'birthdate':'birthyear', 'preferredposition1label': 'position'}, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 rating23_new['birthdate']=rating23_new.apply(lambda x:x['birthdate'].split()[0], axis=1)
#       3 rating23_new['birthdate'] = rating23_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)
#       5 rating23_new = rating23_new.rename({'fullNameForSearch':'full_name', 'birthdate':'birthyear', 'preferredposition1label': 'position'}, axis=1)
#
# File ~\anaconda3\envs\WC2023\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\WC2023\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\envs\WC2023\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\envs\WC2023\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[36], line 1, in <lambda>(x)
# ----> 1 rating23_new['birthdate']=rating23_new.apply(lambda x:x['birthdate'].split()[0], axis=1)
#       3 rating23_new['birthdate'] = rating23_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)
#       5 rating23_new = rating23_new.rename({'fullNameForSearch':'full_name', 'birthdate':'birthyear', 'preferredposition1label': 'position'}, axis=1)
#
# AttributeError: 'int' object has no attribute 'split'

# %%
rating23_new.head()
# Out:
#           fullNameForSearch nationality  birthdate preferredposition1label  \
# 0    Alexia Putellas Segura       Spain       1994                      CM
# 1    Caroline Graham Hansen      Norway       1995                      RW
# 2  Maria Pilar Leon Cebrian       Spain       1995                      CB
# 3   Irene Paredes Hernandez       Spain       1991                      CB
# 4       Sandra Panos Garcia       Spain       1992                      GK
#
#    height  weight  overall_rating  pac  sho  pas  dri  def  phy  longshots  \
# 0     173      67              92   80   90   92   91   72   75         90
# 1     178      66              90   88   84   90   91   48   75         85
# 2     169      61              88   78   58   80   77   91   78         59
# 3     177      62              88   75   54   68   70   90   84         55
# 4     169      65              88   87   84   87   91   46   87         17
#
#    volleys  balance  shotpower  longpassing  standingtackle  crossing  curve  \
# 0       90       78         81           91              82        87     89
# 1       82       75         79           84              50        93     90
# 2       49       75         51           90              90        86     63
# 3       60       65         60           62              87        59     69
# 4       19       70         65           18              18        16     22
#
#    finishing  slidingtackle  aggression  sprintspeed  headingaccuracy  \
# 0         94             64          58           78               74
# 1         86             46          66           88               75
# 2         61             90          88           79               87
# 3         51             87          87           75               88
# 4         11             14          19           50               20
#
#    reactions  ranking  penalties  strength  skillmoves  stamina  ballcontrol  \
# 0         95        1         91        75           5       90           94
# 1         89        8         80        74           5       84           92
# 2         94       13         64        75           2       75           91
# 3         92       14         70        82           2       85           85
# 4         84       17         27        64           1       45           20
#
#    acceleration  preferredfoot  vision  agility  composure  jumping  \
# 0            82              2      95       76         91       75
# 1            88              1      93       85         84       68
# 2            77              2      56       75         70       76
# 3            75              1      51       68         75       79
# 4            44              1      34       54         56       72
#
#    interceptions  shortpassing
# 0             79            95
# 1             35            90
# 2             91            90
# 3             92            84
# 4             19            23

# %%
rating23_new.rename(columns = {'overall_rating':'overall','pac':'pace', 'sho':'shooting', 'pas': 'passing', 
                               'dri':'dribbling','def':'defending'}, inplace = True)

# %%
rating23_2_new = rating23_2[new_col_1]
rating23_2_new['birthdate']=rating23_2_new.apply(lambda x:x['birthdate'].split()[0], axis=1)

rating23_2_new['birthdate'] = rating23_2_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)

rating23_2_new = rating23_2_new.rename({'fullNameForSearch':'full_name', 'birthdate':'birthyear', 'preferredposition1label': 'position'}, axis=1)
rating23_2_new.rename(columns = {'overall_rating':'overall','pac':'pace', 'sho':'shooting', 'pas': 'passing', 
                               'dri':'dribbling','def':'defending'}, inplace = True)
# Out:
# C:\Users\lorih\AppData\Local\Temp\ipykernel_166676\3048508127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating23_2_new['birthdate']=rating23_2_new.apply(lambda x:x['birthdate'].split()[0], axis=1)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_166676\3048508127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating23_2_new['birthdate'] = rating23_2_new.apply(lambda x:datetime.strptime(x['birthdate'], '%m/%d/%Y').year, axis =1)

# %%
rating23_new.columns == rating23_2_new.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
def get_nation(df):
    nation_list = df.nationality.unique()
    nation_dict = {}
    for num in nation_list:
        r = requests.get('https://www.ea.com/games/fifa/fifa-23/womens-ratings/player-filter/player-nationality/'+str(num))
        soup = BeautifulSoup(r.content, 'html.parser')
        title = soup.find('title')
        nation_dict[num] = title.text.split()[0]
    df['nationality'] = df['nationality'].replace(nation_dict)
    return df

# %%
rating23_new = get_nation(rating23_new)

# %%
rating23_2_new = get_nation(rating23_2_new)

# %% [markdown]
# ### Check what players were added or removed

# %%
merged = pd.merge(rating23_new, rating23_2_new, on=['full_name','nationality'], how='outer', indicator=True)

# %%
merged.head()
# Out:
#                 full_name nationality  birthyear_x position_x  height_x  \
# 0  Alexia Putellas Segura       Spain       1994.0         CM     173.0
# 1                Sam Kerr   Australia       1993.0         ST     168.0
# 2           Wendie Renard      France       1990.0         CB     187.0
# 3           Ada Hegerberg      Norway       1995.0         ST     176.0
# 4            Marie Katoto      France       1998.0         ST     177.0
#
#    weight_x  overall_x  pace_x  shooting_x  passing_x  dribbling_x  \
# 0      67.0       92.0    80.0        90.0       92.0         91.0
# 1      66.0       91.0    87.0        91.0       75.0         90.0
# 2      70.0       91.0    67.0        72.0       71.0         72.0
# 3      68.0       91.0    85.0        91.0       77.0         87.0
# 4      66.0       90.0    88.0        90.0       78.0         86.0
#
#    defending_x  phy_x  longshots_x  volleys_x  balance_x  shotpower_x  \
# 0         72.0   75.0         90.0       90.0       78.0         81.0
# 1         42.0   83.0         89.0       92.0       82.0         91.0
# 2         93.0   87.0         65.0       55.0       34.0         85.0
# 3         39.0   77.0         89.0       90.0       47.0         86.0
# 4         39.0   74.0         87.0       91.0       68.0         86.0
#
#    longpassing_x  standingtackle_x  crossing_x  curve_x  finishing_x  \
# 0           91.0              82.0        87.0     89.0         94.0
# 1           55.0              39.0        80.0     76.0         93.0
# 2           87.0              94.0        51.0     65.0         70.0
# 3           72.0              33.0        71.0     79.0         94.0
# 4           70.0              35.0        71.0     71.0         93.0
#
#    slidingtackle_x  aggression_x  sprintspeed_x  headingaccuracy_x  \
# 0             64.0          58.0           78.0               74.0
# 1             35.0          70.0           85.0               91.0
# 2             91.0          88.0           66.0               96.0
# 3             29.0          65.0           86.0               93.0
# 4             29.0          44.0           88.0               92.0
#
#    reactions_x  ranking_x  penalties_x  strength_x  skillmoves_x  stamina_x  \
# 0         95.0        1.0         91.0        75.0           5.0       90.0
# 1         93.0        2.0         79.0        86.0           4.0       87.0
# 2         90.0        3.0         75.0        93.0           2.0       75.0
# 3         93.0        4.0         86.0        81.0           4.0       75.0
# 4         90.0        5.0         82.0        81.0           4.0       82.0
#
#    ballcontrol_x  acceleration_x  preferredfoot_x  vision_x  agility_x  \
# 0           94.0            82.0              2.0      95.0       76.0
# 1           92.0            89.0              1.0      83.0       90.0
# 2           85.0            68.0              1.0      59.0       53.0
# 3           91.0            83.0              1.0      76.0       74.0
# 4           89.0            89.0              1.0      79.0       80.0
#
#    composure_x  jumping_x  interceptions_x  shortpassing_x  birthyear_y  \
# 0         91.0       75.0             79.0            95.0          NaN
# 1         92.0       91.0             24.0            78.0       1993.0
# 2         84.0       86.0             90.0            84.0       1990.0
# 3         86.0       89.0             23.0            84.0       1995.0
# 4         85.0       86.0             27.0            87.0       1998.0
#
#   position_y  height_y  weight_y  overall_y  pace_y  shooting_y  passing_y  \
# 0        NaN       NaN       NaN        NaN     NaN         NaN        NaN
# 1         ST     168.0      66.0       91.0    87.0        91.0       74.0
# 2         CB     187.0      70.0       90.0    62.0        72.0       71.0
# 3         ST     176.0      68.0       90.0    83.0        91.0       77.0
# 4         ST     177.0      66.0       89.0    87.0        90.0       78.0
#
#    dribbling_y  defending_y  phy_y  longshots_y  volleys_y  balance_y  \
# 0          NaN          NaN    NaN          NaN        NaN        NaN
# 1         90.0         42.0   83.0         89.0       92.0       82.0
# 2         71.0         93.0   87.0         65.0       55.0       34.0
# 3         87.0         39.0   77.0         89.0       90.0       47.0
# 4         85.0         39.0   73.0         87.0       91.0       68.0
#
#    shotpower_y  longpassing_y  standingtackle_y  crossing_y  curve_y  \
# 0          NaN            NaN               NaN         NaN      NaN
# 1         91.0           64.0              39.0        70.0     76.0
# 2         85.0           87.0              94.0        51.0     65.0
# 3         86.0           72.0              33.0        71.0     79.0
# 4         86.0           70.0              35.0        71.0     71.0
#
#    finishing_y  slidingtackle_y  aggression_y  sprintspeed_y  \
# 0          NaN              NaN           NaN            NaN
# 1         93.0             30.0          70.0           85.0
# 2         70.0             90.0          88.0           60.0
# 3         94.0             30.0          65.0           85.0
# 4         93.0             29.0          44.0           87.0
#
#    headingaccuracy_y  reactions_y  ranking_y  penalties_y  strength_y  \
# 0                NaN          NaN        NaN          NaN         NaN
# 1               91.0         91.0        1.0         75.0        86.0
# 2               96.0         90.0        3.0         75.0        93.0
# 3               93.0         92.0        4.0         86.0        81.0
# 4               92.0         88.0        7.0         82.0        81.0
#
#    skillmoves_y  stamina_y  ballcontrol_y  acceleration_y  preferredfoot_y  \
# 0           NaN        NaN            NaN             NaN              NaN
# 1           4.0       87.0           92.0            89.0              1.0
# 2           2.0       75.0           81.0            65.0              1.0
# 3           4.0       75.0           91.0            81.0              1.0
# 4           4.0       78.0           88.0            88.0              1.0
#
#    vision_y  agility_y  composure_y  jumping_y  interceptions_y  \
# 0       NaN        NaN          NaN        NaN              NaN
# 1      79.0       90.0         92.0       91.0             24.0
# 2      59.0       53.0         84.0       86.0             90.0
# 3      76.0       74.0         86.0       89.0             23.0
# 4      79.0       80.0         85.0       86.0             27.0
#
#    shortpassing_y     _merge
# 0             NaN  left_only
# 1            78.0       both
# 2            84.0       both
# 3            84.0       both
# 4            86.0       both

# %%
diff = merged.loc[merged['_merge'] != 'both']

# %%
diff = diff[['full_name','nationality', '_merge']]

# %%
FIFA_update = diff.replace({'left_only':'removed', 'right_only':'added'})

# %%
FIFA_update = FIFA_update.rename(columns = {'_merge': 'action'})

# %%
FIFA_update = FIFA_update.sort_values('nationality')

# %%
FIFA_update.action.value_counts()
# Out:
# added      201
# removed    136
# both         0
# Name: action, dtype: int64

# %%
FIFA_update.head()
# Out:
#             full_name nationality   action
# 376    Soledad Jaimes   Argentina  removed
# 295    Eliana Stabile   Argentina  removed
# 408     Adriana Sachs   Argentina  removed
# 397  Agustina Barroso   Argentina  removed
# 373     Emily Gielnik   Australia  removed

# %% [markdown]
# ### Combine two dataset. If a player's rating changed, use the newer one.

# %%
rating23_new.set_index('full_name', inplace=True)
rating23_2_new.set_index('full_name', inplace=True)

# %%
mask = ~rating23_new.index.isin(rating23_2_new.index)

# %%
rating23_new_masked = rating23_new[mask]

# %%
rating23_combined = pd.concat([rating23_new_masked, rating23_2_new])

# %%
rating23_combined.shape
# Out:
# (700, 40)

# %%
rating23_combined.nationality.value_counts()
# Out:
# United         125
# France         108
# England         73
# Germany         42
# Spain           41
# Sweden          28
# Canada          24
# Holland         20
# Scotland        19
# Belgium         16
# Norway          16
# Iceland         15
# Portugal        13
# Mexico          13
# Australia       12
# Denmark         12
# Argentina       11
# China           10
# Wales            9
# Italy            9
# Japan            8
# Switzerland      8
# Poland           7
# Republic         7
# Brazil           5
# Austria          5
# Haiti            5
# Finland          5
# Jamaica          4
# New              4
# Czech            3
# Cameroon         3
# Nigeria          3
# Korea            2
# Slovakia         2
# Costa            2
# Slovenia         2
# Venezuela        1
# Bosnia           1
# Serbia           1
# Côte             1
# Chile            1
# Morocco          1
# Greece           1
# Mali             1
# Russia           1
# Name: nationality, dtype: int64

# %%
rating23_combined.reset_index(inplace = True)

# %%
rating23_combined.to_csv('../Datasets/cleaned_data/FIFA23_rating_combined.csv', index = False)

# %%
rating22_new = rating22[new_col_2]
rating21_new = rating21[new_col_2]
rating20_new = rating20[new_col_2]
rating19_new = rating19[new_col_2]
rating18_new = rating18[new_col_2]
rating17_new = rating17[new_col_2]
rating16_new = rating16[new_col_2]

# %%
rating22_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating21_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating20_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating19_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating18_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating17_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
rating16_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# Out:
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating22_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating21_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating20_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating19_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating18_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating17_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)
# C:\Users\lorih\AppData\Local\Temp\ipykernel_68896\2418996844.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating16_new.rename(columns = {'nationality_name':'nationality', 'height_cm':'height', 'weight_kg': 'weight'}, inplace = True)

# %%
rating22_new.to_csv('../Datasets/cleaned_data/FIFA22_rating_new.csv', index = False)
rating21_new.to_csv('../Datasets/cleaned_data/FIFA21_rating_new.csv', index = False)
rating20_new.to_csv('../Datasets/cleaned_data/FIFA20_rating_new.csv', index = False)
rating19_new.to_csv('../Datasets/cleaned_data/FIFA19_rating_new.csv', index = False)
rating18_new.to_csv('../Datasets/cleaned_data/FIFA18_rating_new.csv', index = False)
rating17_new.to_csv('../Datasets/cleaned_data/FIFA17_rating_new.csv', index = False)
rating16_new.to_csv('../Datasets/cleaned_data/FIFA16_rating_new.csv', index = False)

# %%
rating16_22 = pd.concat([rating16_new, rating17_new, rating18_new, rating19_new, rating20_new, rating21_new, rating22_new], ignore_index = True)

# %%
rating16_22.to_csv('../Datasets/cleaned_data/FIFA16-22_rating_new.csv', index = False)
